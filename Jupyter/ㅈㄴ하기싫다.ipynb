# %%
import pandas as pd
child_h = pd.read_csv('어린이보호구역현황(개방표준).csv', encoding ='CP949')
cctv = pd.read_csv('CCTV현황(개방표준).csv', encoding ='CP949')
walk_child = pd.read_csv('보행어린이사고다발지현황.csv', encoding ='CP949')
kindergarden = pd.read_csv('어린이집및유치원현황.csv', encoding ='CP949')
elementery = pd.read_csv('초등학교현황.csv', encoding ='CP949')
school_number = pd.read_csv('학교현황(학생수)(초,중,고,그외).csv', encoding ='CP949')
child_h.head()
# Out:
#    시설종류       대상시설명              소재지도로명주소                소재지지번주소         위도  \
# 0  어린이집    시립정왕어린이집   경기도 시흥시 정왕대로53번길 38   경기도 시흥시 정왕동 1866-1번지  37.357610
# 1  어린이집    또래또래어린이집   경기도 시흥시 마유로443번길 33   경기도 시흥시 정왕동 2293-7번지  37.354127
# 2  어린이집      큰숲어린이집  경기도 시흥시 오이도중앙로 24-10   경기도 시흥시 정왕동 1998-7번지  37.346481
# 3  어린이집  시립정왕본동어린이집  경기도 시흥시 오동마을로6번안길 17   경기도 시흥시 정왕동 2318-6번지  37.352229
# 4  어린이집    에트라움어린이집   경기도 시흥시 오동마을로5번길 37  경기도 시흥시 정왕동 2315-13번지  37.352406
#
#            경도     관리기관명 관할경찰서명 CCTV설치여부  CCTV설치대수 보호구역도로폭     데이터기준일자
# 0  126.726442  경기도 시흥시청  시흥경찰서        Y       1.0       8  2020-12-02
# 1  126.738627  경기도 시흥시청  시흥경찰서        Y       3.0       4  2020-12-02
# 2  126.689175  경기도 시흥시청  시흥경찰서        Y       1.0       6  2020-12-02
# 3  126.744044  경기도 시흥시청  시흥경찰서        Y       2.0       6  2020-12-02
# 4  126.746119  경기도 시흥시청  시흥경찰서        Y       3.0       6  2020-12-02

# %%
cctv.head()
# Out:
#       관리기관명              소재지도로명주소              소재지지번주소 설치목적구분  카메라대수  카메라화소수  \
# 0  경기도 시흥시청  경기도 시흥시 수인로2421번길 26   경기도 시흥시 논곡동  227-2  어린이보호      1     200
# 1  경기도 시흥시청   경기도 시흥시 봉우순환로 117-7  경기도 시흥시 정왕본동 2245-3  어린이보호      1     130
# 2  경기도 시흥시청   경기도 시흥시 수인로2793번길 6      경기도 시흥시 도창동 118  어린이보호      1     200
# 3  경기도 시흥시청                   NaN     경기도 시흥시 도창동 98-4  어린이보호      1     200
# 4  경기도 시흥시청       경기도 시흥시 매화1로 62    경기도 시흥시 매화동 303-1  어린이보호      1     130
#
#      촬영방면정보  보관일수     설치년월      관리기관전화번호         위도          경도     데이터기준일자
# 0  360도 전방면  30.0  2017-03  031-310-3702  37.392609  126.855264  2017-01-01
# 1  360도 전방면  30.0  2017-03  031-310-3702  37.357223  126.751885  2017-01-01
# 2  360도 전방면  30.0  2017-03  031-310-3702  37.406720  126.823792  2017-01-01
# 3  360도 전방면  30.0  2017-03  031-310-3702  37.409971  126.822294  2017-01-01
# 4  360도 전방면  30.0  2017-03  031-310-3702  37.416184  126.808463  2017-01-01

# %%
walk_child.head()
# Out:
#    시군명 구/읍면동명  사고년도      사고유형구분  다발지역FID   다발지역ID       법정동코드      위치코드  \
# 0  시흥시    장곡동  2018  보행어린이사고다발지  6504068  2019035  4139013000  41390001
# 1  시흥시    정왕동  2017  보행어린이사고다발지  6395217  2018028  4139013200  41390001
# 2  시흥시    거모동  2015  보행어린이사고다발지  6169274  2016044  4139012700  41390001
# 3  시흥시    대야동  2015  보행어린이사고다발지  6165550  2016044  4139010100  41390002
# 4  시흥시    거모동  2014  보행어린이사고다발지  6101137  2015049  4139012700  41390001
#
#      시도시군구명                 사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0  경기도 시흥시1  경기도 시흥시 장곡동(진말로9번길 부근)     3     3     0     1     1     1
# 1  경기도 시흥시1    경기도 시흥시 정왕동(큰솔공원 부근)     3     3     1     0     1     1
# 2  경기도 시흥시1   경기도 시흥시 거모동(도일삼거리 부근)     4     4     0     0     2     2
# 3  경기도 시흥시2   경기도 시흥시 대야동(대야오거리 부근)     3     3     0     2     1     0
# 4  경기도 시흥시1   경기도 시흥시 거모동(도일삼거리 부근)     5     6     0     2     3     1
#
#           위도          경도                                        사고다발지역폴리곤정보
# 0  37.378247  126.784444  {"type":"Polygon","coordinates":[[[126.7862410...
# 1  37.343907  126.754119  {"type":"Polygon","coordinates":[[[126.7559152...
# 2  37.343201  126.784811  {"type":"Polygon","coordinates":[[[126.7866074...
# 3  37.448550  126.788354  {"type":"Polygon","coordinates":[[[126.7901506...
# 4  37.343532  126.784573  {"type":"Polygon","coordinates":[[[126.786169,...

# %%
kindergarden.head()
# Out:
#    시군명 시설구분명 공사립구분명             시설명          전화번호  \
# 0  시흥시  어린이집    국공립      시립정왕2동어린이집  031-432-0660
# 1  시흥시  어린이집    국공립  시립정왕보듬이나눔이어린이집  031-431-9555
# 2  시흥시  어린이집    국공립      시립정왕본동어린이집  031-319-7934
# 3  시흥시  어린이집    국공립        시립정왕어린이집  031-496-0015
# 4  시흥시  어린이집    국공립      시립종합복지어린이집  031-311-3751
#
#                          소재지지번주소                      소재지도로명주소  소재지우편번호  \
# 0           경기도 시흥시 정왕동 1849-8번지     경기도 시흥시 정왕대로118번길 5 (정왕동)  15038.0
# 1             경기도 시흥시 정왕동 2132번지            경기도 시흥시 경기과기대로 283  15073.0
# 2           경기도 시흥시 정왕동 2318-6번지    경기도 시흥시 오동마을로6번안길 17 (정왕동)  15049.0
# 3  경기도 시흥시 정왕동 1866-1번지 시립정왕어린이집  경기도 시흥시 정왕대로53번길 38 시립정왕어린이집  15030.0
# 4            경기도 시흥시 대야동 571-3번지     경기도 시흥시 은행로173번길 14 (대야동)  14914.0
#
#      WGS84위도     WGS84경도
# 0  37.351106  126.728462
# 1  37.339850  126.735701
# 2  37.352234  126.744010
# 3  37.357610  126.726454
# 4  37.445518  126.796816

# %%
elementery.head()
# Out:
#    시군명 설립구분명       시설명           전화번호                      소재지지번주소  \
# 0  시흥시    공립  배곧해솔초등학교  031-8063-7802  경기도 시흥시 정왕동 2560번지 배곧해솔초등학교
# 1  시흥시    공립    진말초등학교   070-709-7140     경기도 시흥시 장곡동 827번지 진말초등학교
# 2  시흥시    공립    생금초등학교  070-7016-3004     경기도 시흥시 죽율동 767번지 생금초등학교
# 3  시흥시    공립    서촌초등학교  070-7014-4094         경기도 시흥시 정왕동 1848-1번지
# 4  시흥시    공립    서해초등학교   031-434-6153  경기도 시흥시 정왕동 1867-2번지 서해초등학교
#
#                소재지도로명주소  소재지우편번호    WGS84위도     WGS84경도
# 0  경기도 시흥시 서울대학로 150-17    15011  37.360246  126.718035
# 1      경기도 시흥시 황고개로 567    15002  37.380640  126.787995
# 2     경기도 시흥시 죽율로 45-42    15050  37.349919  126.757282
# 3  경기도 시흥시 정왕대로118번길 27    15038  37.349141  126.727275
# 4   경기도 시흥시 정왕대로53번길 14    15030  37.355857  126.724835

# %%
school_number.head()
# Out:
#    기준년도  시군명      지역교육청명      지역명      학교명  학교급명 설립구분명 주야간명 제외여부  제외사유  \
# 0  2020  시흥시  경기도시흥교육지원청  경기도 시흥시  시흥은행중학교   NaN    공립   주간    N   NaN
# 1  2020  시흥시  경기도시흥교육지원청  경기도 시흥시    시흥중학교   NaN    공립   주간    N   NaN
# 2  2020  시흥시  경기도시흥교육지원청  경기도 시흥시    신천중학교   NaN    공립   주간    N   NaN
# 3  2020  시흥시  경기도시흥교육지원청  경기도 시흥시    연성중학교   NaN    공립   주간    N   NaN
# 4  2020  시흥시  경기도시흥교육지원청  경기도 시흥시    장곡중학교   NaN    공립   주간    N   NaN
#
#    1학년수(명)  2학년수(명)  3학년수(명)  4학년수(명)  5학년수(명)  6학년수(명)  특수학급학생수(명)  \
# 0      362      394      356      NaN      NaN      NaN         7.0
# 1      208      237      185      NaN      NaN      NaN        11.0
# 2       99       84       79      NaN      NaN      NaN        16.0
# 3      209      220      218      NaN      NaN      NaN         5.0
# 4      164      147      151      NaN      NaN      NaN         9.0
#
#    순회학급학생수(명) 합계사항(명)
# 0           0    1119
# 1           0     641
# 2           0     278
# 3           0     652
# 4           0     471
